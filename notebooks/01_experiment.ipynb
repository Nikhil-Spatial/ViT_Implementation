# %%
import torch

# %%
conv = torch.nn.Conv2d(3, 512, 4, stride=4)
conv
# Out:
# Conv2d(3, 512, kernel_size=(4, 4), stride=(4, 4))

# %%
output = conv(torch.randn(16, 3, 32, 32)).reshape((16, 512, 64))
output.shape
# Out:
# torch.Size([16, 512, 64])

# %%
output = output.reshape((16, 512, 64))
output.shape
# Out:
# torch.Size([16, 512, 64])

# %%
output = torch.transpose(output, 1, 2)
output.shape
# Out:
# torch.Size([16, 64, 512])

# %%
torch.cat((output, torch.nn.Parameter(torch.randn(16, 1, 512))), dim=1).shape
# Out:
# torch.Size([16, 65, 512])

# %%
positional_embeddings = torch.nn.Parameter(torch.randn(1, 65, 512))
positional_embeddings.shape
# Out:
# torch.Size([1, 65, 512])

# %%
inputs = torch.randn(256, 65, 512)
inputs.shape
# Out:
# torch.Size([256, 65, 512])

# %%
outputs = inputs + positional_embeddings
outputs.shape
# Out:
# torch.Size([256, 65, 512])

# %%
positional_embeddings[0][0][0], inputs[0][0][0], outputs[0][0][0]
# Out:
# (tensor(-1.2371, grad_fn=<SelectBackward0>),
#  tensor(0.8575),
#  tensor(-0.3796, grad_fn=<SelectBackward0>))

# %%
layer_norm = torch.nn.LayerNorm(512)

inputs = torch.randn(256, 65, 512)

layer_norm(inputs).shape
# Out:
# torch.Size([256, 65, 512])

# %%
Q_linear_transform = torch.nn.Linear(512, 128, bias=False)
K_linear_transform = torch.nn.Linear(512, 128, bias=False)

# %%
inputs = torch.randn(256, 65, 512)
Q = Q_linear_transform(inputs)
K = K_linear_transform(inputs)
Q.shape, K.shape
# Out:
# (torch.Size([256, 65, 128]), torch.Size([256, 65, 128]))

# %%
import math

output = (Q @ K.transpose(-2, -1)) / math.sqrt(128)
output.shape
# Out:
# torch.Size([256, 65, 65])

# %%
from torch.nn.functional import softmax

softmax(output, dim=-1)
# Out:
# tensor([[[0.0236, 0.0159, 0.0292,  ..., 0.0128, 0.0170, 0.0090],
#          [0.0182, 0.0195, 0.0125,  ..., 0.0103, 0.0149, 0.0174],
#          [0.0176, 0.0198, 0.0085,  ..., 0.0218, 0.0273, 0.0140],
#          ...,
#          [0.0131, 0.0117, 0.0136,  ..., 0.0135, 0.0077, 0.0200],
#          [0.0132, 0.0125, 0.0198,  ..., 0.0154, 0.0088, 0.0217],
#          [0.0140, 0.0213, 0.0089,  ..., 0.0108, 0.0108, 0.0385]],
#
#         [[0.0083, 0.0140, 0.0106,  ..., 0.0290, 0.0189, 0.0154],
#          [0.0096, 0.0112, 0.0149,  ..., 0.0125, 0.0088, 0.0165],
#          [0.0209, 0.0178, 0.0143,  ..., 0.0187, 0.0142, 0.0282],
#          ...,
#          [0.0130, 0.0174, 0.0139,  ..., 0.0150, 0.0112, 0.0203],
#          [0.0178, 0.0206, 0.0203,  ..., 0.0098, 0.0176, 0.0121],
#          [0.0070, 0.0211, 0.0139,  ..., 0.0179, 0.0180, 0.0091]],
#
#         [[0.0108, 0.0213, 0.0205,  ..., 0.0216, 0.0182, 0.0231],
#          [0.0084, 0.0160, 0.0188,  ..., 0.0188, 0.0189, 0.0082],
# ...

# %%
head_1 = torch.randn(256, 65, 128)
head_2 = torch.randn(256, 65, 128)
head_3 = torch.randn(256, 65, 128)
head_4 = torch.randn(256, 65, 128)

# %%
output = torch.cat((head_1, head_2, head_3, head_4), dim=-1)
output.shape
# Out:
# torch.Size([256, 65, 512])

# %%
HEADS = 8

# %%
self_attention_heads = [torch.nn.Identity() for _ in range(HEADS)]
self_attention_heads
# Out:
# [Identity(),
#  Identity(),
#  Identity(),
#  Identity(),
#  Identity(),
#  Identity(),
#  Identity(),
#  Identity()]

# %%
inputs = torch.randn(256, 65, 512)

# %%
head_outputs = [self_attention_head(inputs).shape for self_attention_head in self_attention_heads]
head_outputs
# Out:
# [torch.Size([256, 65, 512]),
#  torch.Size([256, 65, 512]),
#  torch.Size([256, 65, 512]),
#  torch.Size([256, 65, 512]),
#  torch.Size([256, 65, 512]),
#  torch.Size([256, 65, 512]),
#  torch.Size([256, 65, 512]),
#  torch.Size([256, 65, 512])]
